# %% [markdown]
# <a href="https://colab.research.google.com/github/cyeef/Turberculosis-USA-/blob/main/TB_worldwide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Continuing practicing of import dataframe and matplot plus .csv data set

# %%
# import panda and matplot
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # create a variable name to utilize the following data set https://public.tableau.com/app/sample-data/TB_Burden_Country.csv?_gl=1*u89cbh*_ga*MTQyNzExMTAxMy4xNzc5NDc2MDcy*_ga_8YLN0SNXVS*czE3Nzk0NzYwNzAkbzEkZzEkdDE3Nzk0NzYwODgkajYwJGwwJGgw*_gcl_au*MTQ2MzMyMTcxOC4xNzc5NDc2MDcy

# %%
# this is my data from Free Public Data Sets for Analysis - pd.read_csv turns file into a data fram
turb_by_country = pd.read_csv('https://public.tableau.com/app/sample-data/TB_Burden_Country.csv?_gl=1*mmud84*_ga*MTQyNzExMTAxMy4xNzc5NDc2MDcy*_ga_8YLN0SNXVS*czE3Nzk0NzYwNzAkbzEkZzEkdDE3Nzk0NzYwODgkajYwJGwwJGgw*_gcl_au*MTQ2MzMyMTcxOC4xNzc5NDc2MDcy')

# type() determines what is the object (int, string, float etc)
type(turb_by_country)
# Out:
# pandas.core.frame.DataFrame

# %%
# check data by running head() to return the first few rows from the data frame
turb_by_country.head()
# Out:
#   Country or territory name ISO 2-character country/territory code  \
# 0               Afghanistan                                     AF
# 1               Afghanistan                                     AF
# 2               Afghanistan                                     AF
# 3               Afghanistan                                     AF
# 4               Afghanistan                                     AF
#
#   ISO 3-character country/territory code  ISO numeric country/territory code  \
# 0                                    AFG                                   4
# 1                                    AFG                                   4
# 2                                    AFG                                   4
# 3                                    AFG                                   4
# 4                                    AFG                                   4
#
#   Region  Year  Estimated total population number  \
# ...

# %%
# plot specific data in the csv - determine what specific data you would like to highlight in any data set

#SET COLUMNS
usa = turb_by_country[turb_by_country["Country or territory name"]== "United States of America"]
print("Rows in usa: ", len(usa))
print(usa["Estimated prevalence of TB (all forms) per 100 000 population"].head())
plt.scatter(usa["Year"], usa["Estimated prevalence of TB (all forms) per 100 000 population"])
plt.xlabel("Year")

plt.title('Data specific to USA')
plt.show()
# Out:
# Rows in usa:  24
# 4832    14.0
# 4833    15.0
# 4834    14.0
# 4835    14.0
# 4836    13.0
# Name: Estimated prevalence of TB (all forms) per 100 000 population, dtype: float64
